# %%
import os
import shutil
import re


dir_list = [
    'results_tf_2_diabetes',
    'results_tf_3_diabetes',
    'results_tf_4_diabetes',
    'results_tf_5_diabetes',
    'results_tf_6_diabetes',
]



# Define date pattern to identify files with dates in their names
date_pattern = re.compile(r'\d{4}-\d{2}-\d{2}')

# Process each directory
for dir_path in dir_list:
    print(f"Processing {dir_path}...")
    
    # Get all date subdirectories
    date_dirs = [d for d in os.listdir(dir_path) if os.path.isdir(os.path.join(dir_path, d))]
    
    # Process each date directory
    for date_dir in date_dirs:
        date_dir_path = os.path.join(dir_path, date_dir)
        
        # Find all CSV files without dates in their names
        for file in os.listdir(date_dir_path):
            if file.endswith('.csv') and not date_pattern.search(file):
                src_file = os.path.join(date_dir_path, file)
                dst_file = os.path.join(dir_path, file)
                
                # Check if destination file already exists
                if os.path.exists(dst_file):
                    print(f"Skipping {file} (already exists in destination)")
                    continue
                
                print(f"Copying {file} from {date_dir} to {dir_path}")
                try:
                    shutil.copy2(src_file, dst_file)
                except Exception as e:
                    print(f"Error copying {file}: {e}")

print("Finished copying files")
# Out:
# Processing results_tf_2_diabetes...
# Copying diabetes_train_n_seed5_constrained.csv from 2025-03-23_20-15-00 to results_tf_2_diabetes
# Copying diabetes_train_n_seed0.csv from 2025-03-24_00-25-18 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed7.csv from 2025-03-24_06-40-36 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed6_constrained.csv from 2025-03-23_22-20-03 to results_tf_2_diabetes
# Copying diabetes_train_n_seed4.csv from 2025-03-24_04-35-30 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed0.csv from 2025-03-24_00-25-16 to results_tf_2_diabetes
# Copying diabetes_train_n_seed3.csv from 2025-03-24_02-30-25 to results_tf_2_diabetes
# Copying diabetes_train_n_seed4_constrained.csv from 2025-03-23_20-14-59 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed0_constrained.csv from 2025-03-23_16-04-45 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed5_constrained.csv from 2025-03-23_20-15-02 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed8.csv from 2025-03-24_08-45-41 to results_tf_2_diabetes
# Copying diabetes_train_n_seed3_constrained.csv from 2025-03-23_18-09-54 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed7_constrained.csv from 2025-03-23_22-20-09 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed5.csv from 2025-03-24_04-35-29 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed6.csv from 2025-03-24_06-40-35 to results_tf_2_diabetes
# Copying diabetes_train_n_seed6.csv from 2025-03-24_06-40-37 to results_tf_2_diabetes
# Copying diabetes_train_n_seed9_constrained.csv from 2025-03-24_00-25-13 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed9.csv from 2025-03-24_08-45-46 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed3.csv from 2025-03-24_02-30-27 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed3.csv from 2025-03-24_02-30-23 to results_tf_2_diabetes
# Copying diabetes_train_n_seed8.csv from 2025-03-24_08-45-43 to results_tf_2_diabetes
# Copying diabetes_train_n_seed0_constrained.csv from 2025-03-23_16-04-47 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed2_constrained.csv from 2025-03-23_18-09-51 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed3_constrained.csv from 2025-03-23_18-09-52 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed1.csv from 2025-03-24_00-25-21 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed0_constrained.csv from 2025-03-23_16-04-49 to results_tf_2_diabetes
# Copying diabetes_train_n_seed5.csv from 2025-03-24_04-35-31 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed4_constrained.csv from 2025-03-23_20-14-57 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed6.csv from 2025-03-24_06-40-39 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed2_constrained.csv from 2025-03-23_18-09-55 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed1_constrained.csv from 2025-03-23_16-04-46 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed1_constrained.csv from 2025-03-23_16-04-50 to results_tf_2_diabetes
# Copying diabetes_train_n_seed9.csv from 2025-03-24_08-45-44 to results_tf_2_diabetes
# Copying diabetes_train_n_seed2_constrained.csv from 2025-03-23_18-09-53 to results_tf_2_diabetes
# Copying diabetes_train_n_seed7.csv from 2025-03-24_06-40-38 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed8_constrained.csv from 2025-03-24_00-25-10 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed1.csv from 2025-03-24_00-25-17 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed0.csv from 2025-03-24_00-25-20 to results_tf_2_diabetes
# Copying diabetes_train_n_seed1.csv from 2025-03-24_00-25-19 to results_tf_2_diabetes
# Copying diabetes_train_n_seed6_constrained.csv from 2025-03-23_22-20-06 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed8_constrained.csv from 2025-03-24_00-25-14 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed8.csv from 2025-03-24_08-45-45 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed7_constrained.csv from 2025-03-23_22-20-05 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed4.csv from 2025-03-24_04-35-28 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed6_constrained.csv from 2025-03-23_22-20-08 to results_tf_2_diabetes
# Copying diabetes_train_n_seed1_constrained.csv from 2025-03-23_16-04-48 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed5_constrained.csv from 2025-03-23_20-14-58 to results_tf_2_diabetes
# Copying diabetes_train_n_seed8_constrained.csv from 2025-03-24_00-25-12 to results_tf_2_diabetes
# Copying diabetes_cp_n_seed9.csv from 2025-03-24_08-45-42 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed5.csv from 2025-03-24_04-35-33 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed9_constrained.csv from 2025-03-24_00-25-15 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed7.csv from 2025-03-24_06-40-40 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed4_constrained.csv from 2025-03-23_20-15-01 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed2.csv from 2025-03-24_02-30-26 to results_tf_2_diabetes
# Copying diabetes_ring_n_seed3_constrained.csv from 2025-03-23_18-09-56 to results_tf_2_diabetes
# Copying diabetes_train_n_seed2.csv from 2025-03-24_02-30-24 to results_tf_2_diabetes
# Copying diabetes_train_n_seed7_constrained.csv from 2025-03-23_22-20-07 to results_tf_2_diabetes
# Processing results_tf_3_diabetes...
# Copying diabetes_ring_n_seed6.csv from 2025-03-25_06-10-37 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed9_constrained.csv from 2025-03-24_23-55-09 to results_tf_3_diabetes
# Copying diabetes_train_n_seed6.csv from 2025-03-25_06-10-35 to results_tf_3_diabetes
# Copying diabetes_train_n_seed2.csv from 2025-03-25_02-00-23 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed9.csv from 2025-03-25_08-15-44 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed4_constrained.csv from 2025-03-24_19-44-56 to results_tf_3_diabetes
# Copying diabetes_train_n_seed5.csv from 2025-03-25_04-05-30 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed3_constrained.csv from 2025-03-24_17-39-55 to results_tf_3_diabetes
# Copying diabetes_train_n_seed8.csv from 2025-03-25_08-15-41 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed0.csv from 2025-03-24_23-55-19 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed0_constrained.csv from 2025-03-24_15-34-48 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed9.csv from 2025-03-25_08-15-40 to results_tf_3_diabetes
# Copying diabetes_train_n_seed1.csv from 2025-03-24_23-55-18 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed2.csv from 2025-03-25_02-00-21 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed4_constrained.csv from 2025-03-24_19-45-00 to results_tf_3_diabetes
# Copying diabetes_train_n_seed6_constrained.csv from 2025-03-24_21-50-04 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed6_constrained.csv from 2025-03-24_21-50-06 to results_tf_3_diabetes
# Copying diabetes_train_n_seed7_constrained.csv from 2025-03-24_21-50-05 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed0.csv from 2025-03-24_23-55-14 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed1.csv from 2025-03-24_23-55-20 to results_tf_3_diabetes
# Copying diabetes_train_n_seed5_constrained.csv from 2025-03-24_19-44-59 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed8.csv from 2025-03-25_08-15-43 to results_tf_3_diabetes
# Copying diabetes_train_n_seed9_constrained.csv from 2025-03-24_23-55-11 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed5.csv from 2025-03-25_04-05-32 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed1_constrained.csv from 2025-03-24_15-34-49 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed3.csv from 2025-03-25_02-00-26 to results_tf_3_diabetes
# Copying diabetes_train_n_seed4.csv from 2025-03-25_04-05-29 to results_tf_3_diabetes
# Copying diabetes_train_n_seed4_constrained.csv from 2025-03-24_19-44-58 to results_tf_3_diabetes
# Copying diabetes_train_n_seed7.csv from 2025-03-25_06-10-36 to results_tf_3_diabetes
# Copying diabetes_train_n_seed1_constrained.csv from 2025-03-24_15-34-47 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed2.csv from 2025-03-25_02-00-25 to results_tf_3_diabetes
# Copying diabetes_train_n_seed0.csv from 2025-03-24_23-55-17 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed6_constrained.csv from 2025-03-24_21-50-02 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed1.csv from 2025-03-24_23-55-16 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed7_constrained.csv from 2025-03-24_21-50-07 to results_tf_3_diabetes
# Copying diabetes_train_n_seed9.csv from 2025-03-25_08-15-42 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed8_constrained.csv from 2025-03-24_23-55-12 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed7.csv from 2025-03-25_06-10-34 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed5.csv from 2025-03-25_04-05-28 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed5_constrained.csv from 2025-03-24_19-45-01 to results_tf_3_diabetes
# Copying diabetes_train_n_seed3.csv from 2025-03-25_02-00-24 to results_tf_3_diabetes
# Copying diabetes_train_n_seed0_constrained.csv from 2025-03-24_15-34-46 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed7.csv from 2025-03-25_06-10-38 to results_tf_3_diabetes
# Copying diabetes_train_n_seed8_constrained.csv from 2025-03-24_23-55-10 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed4.csv from 2025-03-25_04-05-31 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed4.csv from 2025-03-25_04-05-27 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed6.csv from 2025-03-25_06-10-33 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed2_constrained.csv from 2025-03-24_17-39-50 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed0_constrained.csv from 2025-03-24_15-34-44 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed5_constrained.csv from 2025-03-24_19-44-57 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed2_constrained.csv from 2025-03-24_17-39-54 to results_tf_3_diabetes
# Copying diabetes_ring_n_seed9_constrained.csv from 2025-03-24_23-55-13 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed3_constrained.csv from 2025-03-24_17-39-51 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed1_constrained.csv from 2025-03-24_15-34-45 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed8.csv from 2025-03-25_08-15-39 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed8_constrained.csv from 2025-03-24_23-55-08 to results_tf_3_diabetes
# Copying diabetes_train_n_seed2_constrained.csv from 2025-03-24_17-39-52 to results_tf_3_diabetes
# Copying diabetes_train_n_seed3_constrained.csv from 2025-03-24_17-39-53 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed7_constrained.csv from 2025-03-24_21-50-03 to results_tf_3_diabetes
# Copying diabetes_cp_n_seed3.csv from 2025-03-25_02-00-22 to results_tf_3_diabetes
# Processing results_tf_4_diabetes...
# Copying diabetes_ring_n_seed9_constrained.csv from 2025-03-25_19-57-53 to results_tf_4_diabetes
# Copying diabetes_train_n_seed7_constrained.csv from 2025-03-25_17-52-45 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed6_constrained.csv from 2025-03-25_17-52-42 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed0.csv from 2025-03-25_19-57-54 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed4.csv from 2025-03-26_00-08-10 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed3_constrained.csv from 2025-03-25_13-42-30 to results_tf_4_diabetes
# Copying diabetes_train_n_seed9_constrained.csv from 2025-03-25_19-57-51 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed0.csv from 2025-03-25_19-57-58 to results_tf_4_diabetes
# Copying diabetes_train_n_seed5_constrained.csv from 2025-03-25_15-47-38 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed8_constrained.csv from 2025-03-25_19-57-52 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed9.csv from 2025-03-26_04-18-24 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed2_constrained.csv from 2025-03-25_13-42-29 to results_tf_4_diabetes
# Copying diabetes_train_n_seed4_constrained.csv from 2025-03-25_15-47-37 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed2.csv from 2025-03-25_22-03-04 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed3.csv from 2025-03-25_22-03-05 to results_tf_4_diabetes
# Copying diabetes_train_n_seed8_constrained.csv from 2025-03-25_19-57-50 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed8_constrained.csv from 2025-03-25_19-57-48 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed9_constrained.csv from 2025-03-25_19-57-49 to results_tf_4_diabetes
# Copying diabetes_train_n_seed1.csv from 2025-03-25_19-57-57 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed6.csv from 2025-03-26_02-13-17 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed8.csv from 2025-03-26_04-18-23 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed7.csv from 2025-03-26_02-13-18 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed1.csv from 2025-03-25_19-57-59 to results_tf_4_diabetes
# Copying diabetes_ring_n_seed5.csv from 2025-03-26_00-08-12 to results_tf_4_diabetes
# Copying diabetes_train_n_seed6_constrained.csv from 2025-03-25_17-52-44 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed7_constrained.csv from 2025-03-25_17-52-43 to results_tf_4_diabetes
# Copying diabetes_train_n_seed0.csv from 2025-03-25_19-57-56 to results_tf_4_diabetes
# Copying diabetes_cp_n_seed1.csv from 2025-03-25_19-57-55 to results_tf_4_diabetes
# Processing results_tf_5_diabetes...
# Copying diabetes_ring_n_seed8_constrained.csv from 2025-03-26_21-36-03 to results_tf_5_diabetes
# Copying diabetes_train_n_seed7_constrained.csv from 2025-03-26_19-30-56 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed9.csv from 2025-03-27_05-56-35 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed7.csv from 2025-03-27_03-51-29 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed3_constrained.csv from 2025-03-26_15-20-41 to results_tf_5_diabetes
# Copying diabetes_train_n_seed0.csv from 2025-03-26_21-36-07 to results_tf_5_diabetes
# Copying diabetes_train_n_seed2_constrained.csv from 2025-03-26_15-20-42 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed3_constrained.csv from 2025-03-26_15-20-46 to results_tf_5_diabetes
# Copying diabetes_train_n_seed6_constrained.csv from 2025-03-26_19-30-55 to results_tf_5_diabetes
# Copying diabetes_train_n_seed9_constrained.csv from 2025-03-26_21-36-02 to results_tf_5_diabetes
# Copying diabetes_train_n_seed6.csv from 2025-03-27_03-51-26 to results_tf_5_diabetes
# Copying diabetes_train_n_seed3_constrained.csv from 2025-03-26_15-20-43 to results_tf_5_diabetes
# Copying diabetes_train_n_seed4.csv from 2025-03-27_01-46-19 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed9.csv from 2025-03-27_05-56-31 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed3.csv from 2025-03-26_23-41-16 to results_tf_5_diabetes
# Copying diabetes_train_n_seed1.csv from 2025-03-26_21-36-08 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed2_constrained.csv from 2025-03-26_15-20-45 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed6_constrained.csv from 2025-03-26_19-30-57 to results_tf_5_diabetes
# Copying diabetes_train_n_seed8.csv from 2025-03-27_05-56-32 to results_tf_5_diabetes
# Copying diabetes_train_n_seed1_constrained.csv from 2025-03-26_13-15-37 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed5_constrained.csv from 2025-03-26_17-25-48 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed7_constrained.csv from 2025-03-26_19-30-54 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed2_constrained.csv from 2025-03-26_15-20-40 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed1.csv from 2025-03-26_21-36-10 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed4_constrained.csv from 2025-03-26_17-25-51 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed9_constrained.csv from 2025-03-26_21-36-00 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed8_constrained.csv from 2025-03-26_21-35-59 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed5.csv from 2025-03-27_01-46-18 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed7.csv from 2025-03-27_03-51-25 to results_tf_5_diabetes
# Copying diabetes_train_n_seed4_constrained.csv from 2025-03-26_17-25-49 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed0.csv from 2025-03-26_21-36-09 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed6.csv from 2025-03-27_03-51-24 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed3.csv from 2025-03-26_23-41-12 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed4_constrained.csv from 2025-03-26_17-25-47 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed2.csv from 2025-03-26_23-41-11 to results_tf_5_diabetes
# Copying diabetes_train_n_seed8_constrained.csv from 2025-03-26_21-36-01 to results_tf_5_diabetes
# Copying diabetes_train_n_seed0_constrained.csv from 2025-03-26_13-15-36 to results_tf_5_diabetes
# Copying diabetes_cp_n_seed4.csv from 2025-03-27_01-46-17 to results_tf_5_diabetes
# Copying diabetes_train_n_seed5_constrained.csv from 2025-03-26_17-25-50 to results_tf_5_diabetes
# Copying diabetes_ring_n_seed5.csv from 2025-03-27_01-46-23 to results_tf_5_diabetes
# Copying diabetes_train_n_seed2.csv from 2025-03-26_23-41-13 to results_tf_5_diabetes
# Processing results_tf_6_diabetes...
# Copying diabetes_cp_n_seed5_constrained.csv from 2025-03-27_14-32-47 to results_tf_6_diabetes
# Copying diabetes_train_n_seed4.csv from 2025-03-27_22-53-19 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed5.csv from 2025-03-27_22-53-18 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed7.csv from 2025-03-28_00-58-24 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed7_constrained.csv from 2025-03-27_16-37-57 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed3.csv from 2025-03-27_20-48-16 to results_tf_6_diabetes
# Copying diabetes_train_n_seed4_constrained.csv from 2025-03-27_14-32-48 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed7_constrained.csv from 2025-03-27_16-37-53 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed0.csv from 2025-03-27_18-43-08 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed1_constrained.csv from 2025-03-27_10-22-38 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed9.csv from 2025-03-28_03-03-30 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed1_constrained.csv from 2025-03-27_10-22-34 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed9_constrained.csv from 2025-03-27_18-42-59 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed0.csv from 2025-03-27_18-43-04 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed9.csv from 2025-03-28_03-03-34 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed1.csv from 2025-03-27_18-43-09 to results_tf_6_diabetes
# Copying diabetes_train_n_seed6.csv from 2025-03-28_00-58-25 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed3_constrained.csv from 2025-03-27_12-27-41 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed3.csv from 2025-03-27_20-48-11 to results_tf_6_diabetes
# Copying diabetes_train_n_seed1.csv from 2025-03-27_18-43-07 to results_tf_6_diabetes
# Copying diabetes_train_n_seed2_constrained.csv from 2025-03-27_12-27-42 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed3_constrained.csv from 2025-03-27_12-27-45 to results_tf_6_diabetes
# Copying diabetes_train_n_seed0_constrained.csv from 2025-03-27_10-22-35 to results_tf_6_diabetes
# Copying diabetes_train_n_seed8_constrained.csv from 2025-03-27_18-43-00 to results_tf_6_diabetes
# Copying diabetes_train_n_seed0.csv from 2025-03-27_18-43-06 to results_tf_6_diabetes
# Copying diabetes_train_n_seed6_constrained.csv from 2025-03-27_16-37-54 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed5_constrained.csv from 2025-03-27_14-32-51 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed6_constrained.csv from 2025-03-27_16-37-52 to results_tf_6_diabetes
# Copying diabetes_train_n_seed2.csv from 2025-03-27_20-48-12 to results_tf_6_diabetes
# Copying diabetes_cp_n_seed1.csv from 2025-03-27_18-43-05 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed5.csv from 2025-03-27_22-53-22 to results_tf_6_diabetes
# Copying diabetes_ring_n_seed7.csv from 2025-03-28_00-58-28 to results_tf_6_diabetes
# Copying diabetes_train_n_seed8.csv from 2025-03-28_03-03-31 to results_tf_6_diabetes
# Finished copying files

# %%
import os
import pandas as pd


dir_list = [
    'results_tf_2_diabetes',
    'results_tf_3_diabetes',
    'results_tf_4_diabetes',
    'results_tf_5_diabetes',
    'results_tf_6_diabetes',
]

result_df_list = []

for dir_path in dir_list:
    print(f"\n{'='*80}")
    print(f"ANALYZING DIRECTORY: {dir_path}")
    print(f"{'='*80}")

    # Get all CSV files in the directory (excluding those in date subdirectories)
    existing_files = [f for f in os.listdir(dir_path) 
                    if f.endswith('.csv') and os.path.isfile(os.path.join(dir_path, f))]

    # Define the expected file pattern
    types = ["cp", "ring", "train"]
    seeds = list(range(10))  # 0 to 9
    constrained = [True, False]  # With and without _constrained suffix

    # Create a list of all expected filenames
    expected_files = []
    for t in types:
        for s in seeds:
            for c in constrained:
                suffix = "_constrained" if c else ""
                filename = f"diabetes_{t}_n_seed{s}{suffix}.csv"
                expected_files.append(filename)

    # Find missing files
    missing_files = [f for f in expected_files if f not in existing_files]

    # Group missing files by type for better readability
    missing_by_type = {t: [] for t in types}
    for file in missing_files:
        for t in types:
            if f"_{t}_" in file:
                missing_by_type[t].append(file)

    # Create a DataFrame for visualization
    rows = []
    for t in types:
        for s in seeds:
            row = {"type": t, "seed": s}
            row["constrained"] = f"diabetes_{t}_n_seed{s}_constrained.csv" not in missing_files
            row["non_constrained"] = f"diabetes_{t}_n_seed{s}.csv" not in missing_files
            rows.append(row)

    df = pd.DataFrame(rows)

    # Display summary
    print(f"Directory: {dir_path}")
    print(f"Total expected files: {len(expected_files)}")
    print(f"Found files: {len(existing_files)}")
    print(f"Missing files: {len(missing_files)}")

    # Display missing files by type
    print("\nMissing files by type:")
    for t in types:
        print(f"\n{t.upper()} - Missing {len(missing_by_type[t])} files:")
        for f in missing_by_type[t]:
            print(f"  - {f}")

    # Display in table format
    print("\nAvailability table (True = file exists, False = file missing):")
    print(df.pivot(index="seed", columns="type"))

    # Append to list
    result_df_list.append(df)

    print()
# Out:
# ================================================================================
# ANALYZING DIRECTORY: results_tf_2_diabetes
# ================================================================================
# Directory: results_tf_2_diabetes
# Total expected files: 60
# Found files: 57
# Missing files: 3
#
# Missing files by type:
#
# CP - Missing 2 files:
#   - diabetes_cp_n_seed2.csv
#   - diabetes_cp_n_seed9_constrained.csv
#
# RING - Missing 1 files:
#   - diabetes_ring_n_seed4.csv
#
# TRAIN - Missing 0 files:
#
# Availability table (True = file exists, False = file missing):
#      constrained             non_constrained
# type          cp  ring train              cp   ring train
# seed
# 0           True  True  True            True   True  True
# 1           True  True  True            True   True  True
# 2           True  True  True           False   True  True
# 3           True  True  True            True   True  True
# 4           True  True  True            True  False  True
# 5           True  True  True            True   True  True
# 6           True  True  True            True   True  True
# 7           True  True  True            True   True  True
# 8           True  True  True            True   True  True
# 9          False  True  True            True   True  True
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_3_diabetes
# ================================================================================
# Directory: results_tf_3_diabetes
# Total expected files: 60
# Found files: 60
# Missing files: 0
#
# Missing files by type:
#
# CP - Missing 0 files:
#
# RING - Missing 0 files:
#
# TRAIN - Missing 0 files:
#
# Availability table (True = file exists, False = file missing):
#      constrained             non_constrained
# type          cp  ring train              cp  ring train
# seed
# 0           True  True  True            True  True  True
# 1           True  True  True            True  True  True
# 2           True  True  True            True  True  True
# 3           True  True  True            True  True  True
# 4           True  True  True            True  True  True
# 5           True  True  True            True  True  True
# 6           True  True  True            True  True  True
# 7           True  True  True            True  True  True
# 8           True  True  True            True  True  True
# 9           True  True  True            True  True  True
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_4_diabetes
# ================================================================================
# Directory: results_tf_4_diabetes
# Total expected files: 60
# Found files: 28
# Missing files: 32
#
# Missing files by type:
#
# CP - Missing 12 files:
#   - diabetes_cp_n_seed0_constrained.csv
#   - diabetes_cp_n_seed1_constrained.csv
#   - diabetes_cp_n_seed2.csv
#   - diabetes_cp_n_seed3.csv
#   - diabetes_cp_n_seed4_constrained.csv
#   - diabetes_cp_n_seed4.csv
#   - diabetes_cp_n_seed5_constrained.csv
#   - diabetes_cp_n_seed5.csv
#   - diabetes_cp_n_seed6.csv
#   - diabetes_cp_n_seed7.csv
#   - diabetes_cp_n_seed8.csv
#   - diabetes_cp_n_seed9.csv
#
# RING - Missing 8 files:
#   - diabetes_ring_n_seed0_constrained.csv
#   - diabetes_ring_n_seed1_constrained.csv
#   - diabetes_ring_n_seed2_constrained.csv
#   - diabetes_ring_n_seed3_constrained.csv
#   - diabetes_ring_n_seed4_constrained.csv
#   - diabetes_ring_n_seed5_constrained.csv
#   - diabetes_ring_n_seed6_constrained.csv
#   - diabetes_ring_n_seed7_constrained.csv
#
# TRAIN - Missing 12 files:
#   - diabetes_train_n_seed0_constrained.csv
#   - diabetes_train_n_seed1_constrained.csv
#   - diabetes_train_n_seed2_constrained.csv
#   - diabetes_train_n_seed2.csv
#   - diabetes_train_n_seed3_constrained.csv
#   - diabetes_train_n_seed3.csv
#   - diabetes_train_n_seed4.csv
#   - diabetes_train_n_seed5.csv
#   - diabetes_train_n_seed6.csv
#   - diabetes_train_n_seed7.csv
#   - diabetes_train_n_seed8.csv
#   - diabetes_train_n_seed9.csv
#
# Availability table (True = file exists, False = file missing):
#      constrained               non_constrained
# type          cp   ring  train              cp  ring  train
# seed
# 0          False  False  False            True  True   True
# 1          False  False  False            True  True   True
# 2           True  False  False           False  True  False
# 3           True  False  False           False  True  False
# 4          False  False   True           False  True  False
# 5          False  False   True           False  True  False
# 6           True  False   True           False  True  False
# 7           True  False   True           False  True  False
# 8           True   True   True           False  True  False
# 9           True   True   True           False  True  False
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_5_diabetes
# ================================================================================
# Directory: results_tf_5_diabetes
# Total expected files: 60
# Found files: 41
# Missing files: 19
#
# Missing files by type:
#
# CP - Missing 6 files:
#   - diabetes_cp_n_seed0_constrained.csv
#   - diabetes_cp_n_seed0.csv
#   - diabetes_cp_n_seed1_constrained.csv
#   - diabetes_cp_n_seed1.csv
#   - diabetes_cp_n_seed6_constrained.csv
#   - diabetes_cp_n_seed8.csv
#
# RING - Missing 9 files:
#   - diabetes_ring_n_seed0_constrained.csv
#   - diabetes_ring_n_seed1_constrained.csv
#   - diabetes_ring_n_seed2.csv
#   - diabetes_ring_n_seed4.csv
#   - diabetes_ring_n_seed5_constrained.csv
#   - diabetes_ring_n_seed6.csv
#   - diabetes_ring_n_seed7_constrained.csv
#   - diabetes_ring_n_seed8.csv
#   - diabetes_ring_n_seed9_constrained.csv
#
# TRAIN - Missing 4 files:
#   - diabetes_train_n_seed3.csv
#   - diabetes_train_n_seed5.csv
#   - diabetes_train_n_seed7.csv
#   - diabetes_train_n_seed9.csv
#
# Availability table (True = file exists, False = file missing):
#      constrained              non_constrained
# type          cp   ring train              cp   ring  train
# seed
# 0          False  False  True           False   True   True
# 1          False  False  True           False   True   True
# 2           True   True  True            True  False   True
# 3           True   True  True            True   True  False
# 4           True   True  True            True  False   True
# 5           True  False  True            True   True  False
# 6          False   True  True            True  False   True
# 7           True  False  True            True   True  False
# 8           True   True  True           False  False   True
# 9           True  False  True            True   True  False
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_6_diabetes
# ================================================================================
# Directory: results_tf_6_diabetes
# Total expected files: 60
# Found files: 33
# Missing files: 27
#
# Missing files by type:
#
# CP - Missing 8 files:
#   - diabetes_cp_n_seed0_constrained.csv
#   - diabetes_cp_n_seed2_constrained.csv
#   - diabetes_cp_n_seed2.csv
#   - diabetes_cp_n_seed4_constrained.csv
#   - diabetes_cp_n_seed4.csv
#   - diabetes_cp_n_seed6.csv
#   - diabetes_cp_n_seed8_constrained.csv
#   - diabetes_cp_n_seed8.csv
#
# RING - Missing 10 files:
#   - diabetes_ring_n_seed0_constrained.csv
#   - diabetes_ring_n_seed2_constrained.csv
#   - diabetes_ring_n_seed2.csv
#   - diabetes_ring_n_seed4_constrained.csv
#   - diabetes_ring_n_seed4.csv
#   - diabetes_ring_n_seed6_constrained.csv
#   - diabetes_ring_n_seed6.csv
#   - diabetes_ring_n_seed8_constrained.csv
#   - diabetes_ring_n_seed8.csv
#   - diabetes_ring_n_seed9_constrained.csv
#
# TRAIN - Missing 9 files:
#   - diabetes_train_n_seed1_constrained.csv
#   - diabetes_train_n_seed3_constrained.csv
#   - diabetes_train_n_seed3.csv
#   - diabetes_train_n_seed5_constrained.csv
#   - diabetes_train_n_seed5.csv
#   - diabetes_train_n_seed7_constrained.csv
#   - diabetes_train_n_seed7.csv
#   - diabetes_train_n_seed9_constrained.csv
#   - diabetes_train_n_seed9.csv
#
# Availability table (True = file exists, False = file missing):
#      constrained               non_constrained
# type          cp   ring  train              cp   ring  train
# seed
# 0          False  False   True            True   True   True
# 1           True   True  False            True   True   True
# 2          False  False   True           False  False   True
# 3           True   True  False            True   True  False
# 4          False  False   True           False  False   True
# 5           True   True  False            True   True  False
# 6           True  False   True           False  False   True
# 7           True   True  False            True   True  False
# 8          False  False   True           False  False   True
# 9           True  False  False            True   True  False

# %%
result_df_list[0]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0         True             True
# 1      cp     1         True             True
# 2      cp     2         True            False
# 3      cp     3         True             True
# 4      cp     4         True             True
# 5      cp     5         True             True
# 6      cp     6         True             True
# 7      cp     7         True             True
# 8      cp     8         True             True
# 9      cp     9        False             True
# 10   ring     0         True             True
# 11   ring     1         True             True
# 12   ring     2         True             True
# 13   ring     3         True             True
# 14   ring     4         True            False
# 15   ring     5         True             True
# 16   ring     6         True             True
# 17   ring     7         True             True
# 18   ring     8         True             True
# 19   ring     9         True             True
# 20  train     0         True             True
# 21  train     1         True             True
# 22  train     2         True             True
# 23  train     3         True             True
# 24  train     4         True             True
# 25  train     5         True             True
# 26  train     6         True             True
# 27  train     7         True             True
# 28  train     8         True             True
# 29  train     9         True             True

# %%
result_df_list[1]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0         True             True
# 1      cp     1         True             True
# 2      cp     2         True             True
# 3      cp     3         True             True
# 4      cp     4         True             True
# 5      cp     5         True             True
# 6      cp     6         True             True
# 7      cp     7         True             True
# 8      cp     8         True             True
# 9      cp     9         True             True
# 10   ring     0         True             True
# 11   ring     1         True             True
# 12   ring     2         True             True
# 13   ring     3         True             True
# 14   ring     4         True             True
# 15   ring     5         True             True
# 16   ring     6         True             True
# 17   ring     7         True             True
# 18   ring     8         True             True
# 19   ring     9         True             True
# 20  train     0         True             True
# 21  train     1         True             True
# 22  train     2         True             True
# 23  train     3         True             True
# 24  train     4         True             True
# 25  train     5         True             True
# 26  train     6         True             True
# 27  train     7         True             True
# 28  train     8         True             True
# 29  train     9         True             True

# %%
result_df_list[2]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0        False             True
# 1      cp     1        False             True
# 2      cp     2         True            False
# 3      cp     3         True            False
# 4      cp     4        False            False
# 5      cp     5        False            False
# 6      cp     6         True            False
# 7      cp     7         True            False
# 8      cp     8         True            False
# 9      cp     9         True            False
# 10   ring     0        False             True
# 11   ring     1        False             True
# 12   ring     2        False             True
# 13   ring     3        False             True
# 14   ring     4        False             True
# 15   ring     5        False             True
# 16   ring     6        False             True
# 17   ring     7        False             True
# 18   ring     8         True             True
# 19   ring     9         True             True
# 20  train     0        False             True
# 21  train     1        False             True
# 22  train     2        False            False
# 23  train     3        False            False
# 24  train     4         True            False
# 25  train     5         True            False
# 26  train     6         True            False
# 27  train     7         True            False
# 28  train     8         True            False
# 29  train     9         True            False

# %%
result_df_list[3]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0        False            False
# 1      cp     1        False            False
# 2      cp     2         True             True
# 3      cp     3         True             True
# 4      cp     4         True             True
# 5      cp     5         True             True
# 6      cp     6        False             True
# 7      cp     7         True             True
# 8      cp     8         True            False
# 9      cp     9         True             True
# 10   ring     0        False             True
# 11   ring     1        False             True
# 12   ring     2         True            False
# 13   ring     3         True             True
# 14   ring     4         True            False
# 15   ring     5        False             True
# 16   ring     6         True            False
# 17   ring     7        False             True
# 18   ring     8         True            False
# 19   ring     9        False             True
# 20  train     0         True             True
# 21  train     1         True             True
# 22  train     2         True             True
# 23  train     3         True            False
# 24  train     4         True             True
# 25  train     5         True            False
# 26  train     6         True             True
# 27  train     7         True            False
# 28  train     8         True             True
# 29  train     9         True            False

# %%
result_df_list[4]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0        False             True
# 1      cp     1         True             True
# 2      cp     2        False            False
# 3      cp     3         True             True
# 4      cp     4        False            False
# 5      cp     5         True             True
# 6      cp     6         True            False
# 7      cp     7         True             True
# 8      cp     8        False            False
# 9      cp     9         True             True
# 10   ring     0        False             True
# 11   ring     1         True             True
# 12   ring     2        False            False
# 13   ring     3         True             True
# 14   ring     4        False            False
# 15   ring     5         True             True
# 16   ring     6        False            False
# 17   ring     7         True             True
# 18   ring     8        False            False
# 19   ring     9        False             True
# 20  train     0         True             True
# 21  train     1        False             True
# 22  train     2         True             True
# 23  train     3        False            False
# 24  train     4         True             True
# 25  train     5        False            False
# 26  train     6         True             True
# 27  train     7        False            False
# 28  train     8         True             True
# 29  train     9        False            False

# %%
import os
import pandas as pd

minimum_num = 50

dir_list = [
    'results_tf_2_diabetes',
    'results_tf_3_diabetes',
    'results_tf_4_diabetes',
    'results_tf_5_diabetes',
    'results_tf_6_diabetes',
]

for dir_path in dir_list:
    print(f"\n{'='*80}")
    print(f"CHECKING FILE SIZES IN: {dir_path}")
    print(f"{'='*80}")
    
    # Get all CSV files in the directory
    csv_files = [f for f in os.listdir(dir_path) 
                if f.endswith('.csv') and os.path.isfile(os.path.join(dir_path, f))]
    
    # Check each file for row count
    small_files = []
    for file in csv_files:
        file_path = os.path.join(dir_path, file)
        try:
            df = pd.read_csv(file_path)
            row_count = len(df)
            
            if row_count <= minimum_num:
                small_files.append((file, row_count))
                print(f"Small file found: {file} - Only {row_count} rows")
        except Exception as e:
            print(f"Error reading {file}: {str(e)}")
    
    # Summary
    if small_files:
        print(f"\nFound {len(small_files)} small files in {dir_path}:")
        for file, count in small_files:
            print(f"  - {file}: {count} rows")
    else:
        print(f"\nNo small files (<={minimum_num} rows) found in {dir_path}")
# Out:
# ================================================================================
# CHECKING FILE SIZES IN: results_tf_2_diabetes
# ================================================================================
# Small file found: diabetes_cp_n_seed9.csv - Only 49 rows
#
# Found 1 small files in results_tf_2_diabetes:
#   - diabetes_cp_n_seed9.csv: 49 rows
#
# ================================================================================
# CHECKING FILE SIZES IN: results_tf_3_diabetes
# ================================================================================
#
# No small files (<=50 rows) found in results_tf_3_diabetes
#
# ================================================================================
# CHECKING FILE SIZES IN: results_tf_4_diabetes
# ================================================================================
#
# No small files (<=50 rows) found in results_tf_4_diabetes
#
# ================================================================================
# CHECKING FILE SIZES IN: results_tf_5_diabetes
# ================================================================================
#
# No small files (<=50 rows) found in results_tf_5_diabetes
#
# ================================================================================
# CHECKING FILE SIZES IN: results_tf_6_diabetes
# ================================================================================
#
# No small files (<=50 rows) found in results_tf_6_diabetes

# %% [markdown]
# # フィルター後

# %%
import os
import pandas as pd


dir_list = [
    'results_tf_2_diabetes',
    'results_tf_3_diabetes',
    'results_tf_4_diabetes',
    'results_tf_5_diabetes',
    'results_tf_6_diabetes',
]

result_df_list = []

for dir_path in dir_list:
    print(f"\n{'='*80}")
    print(f"ANALYZING DIRECTORY: {dir_path}")
    print(f"{'='*80}")

    # Get all CSV files in the directory (excluding those in date subdirectories)
    existing_files = [f for f in os.listdir(dir_path) 
                    if f.endswith('.csv') and os.path.isfile(os.path.join(dir_path, f))]

    # Define the expected file pattern
    types = ["cp", "ring", "train"]
    seeds = list(range(10))  # 0 to 9
    constrained = [True, False]  # With and without _constrained suffix

    # Create a list of all expected filenames
    expected_files = []
    for t in types:
        for s in seeds:
            for c in constrained:
                suffix = "_constrained" if c else ""
                filename = f"diabetes_{t}_n_seed{s}{suffix}.csv"
                expected_files.append(filename)

    # Find missing files
    missing_files = [f for f in expected_files if f not in existing_files]

    # Group missing files by type for better readability
    missing_by_type = {t: [] for t in types}
    for file in missing_files:
        for t in types:
            if f"_{t}_" in file:
                missing_by_type[t].append(file)

    # Create a DataFrame for visualization
    rows = []
    for t in types:
        for s in seeds:
            row = {"type": t, "seed": s}
            row["constrained"] = f"diabetes_{t}_n_seed{s}_constrained.csv" not in missing_files
            row["non_constrained"] = f"diabetes_{t}_n_seed{s}.csv" not in missing_files
            rows.append(row)

    df = pd.DataFrame(rows)

    # Display summary
    print(f"Directory: {dir_path}")
    print(f"Total expected files: {len(expected_files)}")
    print(f"Found files: {len(existing_files)}")
    print(f"Missing files: {len(missing_files)}")

    # Display missing files by type
    print("\nMissing files by type:")
    for t in types:
        print(f"\n{t.upper()} - Missing {len(missing_by_type[t])} files:")
        for f in missing_by_type[t]:
            print(f"  - {f}")

    # Display in table format
    print("\nAvailability table (True = file exists, False = file missing):")
    print(df.pivot(index="seed", columns="type"))

    # Append to list
    result_df_list.append(df)

    print()
# Out:
# ================================================================================
# ANALYZING DIRECTORY: results_tf_2_diabetes
# ================================================================================
# Directory: results_tf_2_diabetes
# Total expected files: 60
# Found files: 56
# Missing files: 4
#
# Missing files by type:
#
# CP - Missing 3 files:
#   - diabetes_cp_n_seed2.csv
#   - diabetes_cp_n_seed9_constrained.csv
#   - diabetes_cp_n_seed9.csv
#
# RING - Missing 1 files:
#   - diabetes_ring_n_seed4.csv
#
# TRAIN - Missing 0 files:
#
# Availability table (True = file exists, False = file missing):
#      constrained             non_constrained
# type          cp  ring train              cp   ring train
# seed
# 0           True  True  True            True   True  True
# 1           True  True  True            True   True  True
# 2           True  True  True           False   True  True
# 3           True  True  True            True   True  True
# 4           True  True  True            True  False  True
# 5           True  True  True            True   True  True
# 6           True  True  True            True   True  True
# 7           True  True  True            True   True  True
# 8           True  True  True            True   True  True
# 9          False  True  True           False   True  True
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_3_diabetes
# ================================================================================
# Directory: results_tf_3_diabetes
# Total expected files: 60
# Found files: 60
# Missing files: 0
#
# Missing files by type:
#
# CP - Missing 0 files:
#
# RING - Missing 0 files:
#
# TRAIN - Missing 0 files:
#
# Availability table (True = file exists, False = file missing):
#      constrained             non_constrained
# type          cp  ring train              cp  ring train
# seed
# 0           True  True  True            True  True  True
# 1           True  True  True            True  True  True
# 2           True  True  True            True  True  True
# 3           True  True  True            True  True  True
# 4           True  True  True            True  True  True
# 5           True  True  True            True  True  True
# 6           True  True  True            True  True  True
# 7           True  True  True            True  True  True
# 8           True  True  True            True  True  True
# 9           True  True  True            True  True  True
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_4_diabetes
# ================================================================================
# Directory: results_tf_4_diabetes
# Total expected files: 60
# Found files: 28
# Missing files: 32
#
# Missing files by type:
#
# CP - Missing 12 files:
#   - diabetes_cp_n_seed0_constrained.csv
#   - diabetes_cp_n_seed1_constrained.csv
#   - diabetes_cp_n_seed2.csv
#   - diabetes_cp_n_seed3.csv
#   - diabetes_cp_n_seed4_constrained.csv
#   - diabetes_cp_n_seed4.csv
#   - diabetes_cp_n_seed5_constrained.csv
#   - diabetes_cp_n_seed5.csv
#   - diabetes_cp_n_seed6.csv
#   - diabetes_cp_n_seed7.csv
#   - diabetes_cp_n_seed8.csv
#   - diabetes_cp_n_seed9.csv
#
# RING - Missing 8 files:
#   - diabetes_ring_n_seed0_constrained.csv
#   - diabetes_ring_n_seed1_constrained.csv
#   - diabetes_ring_n_seed2_constrained.csv
#   - diabetes_ring_n_seed3_constrained.csv
#   - diabetes_ring_n_seed4_constrained.csv
#   - diabetes_ring_n_seed5_constrained.csv
#   - diabetes_ring_n_seed6_constrained.csv
#   - diabetes_ring_n_seed7_constrained.csv
#
# TRAIN - Missing 12 files:
#   - diabetes_train_n_seed0_constrained.csv
#   - diabetes_train_n_seed1_constrained.csv
#   - diabetes_train_n_seed2_constrained.csv
#   - diabetes_train_n_seed2.csv
#   - diabetes_train_n_seed3_constrained.csv
#   - diabetes_train_n_seed3.csv
#   - diabetes_train_n_seed4.csv
#   - diabetes_train_n_seed5.csv
#   - diabetes_train_n_seed6.csv
#   - diabetes_train_n_seed7.csv
#   - diabetes_train_n_seed8.csv
#   - diabetes_train_n_seed9.csv
#
# Availability table (True = file exists, False = file missing):
#      constrained               non_constrained
# type          cp   ring  train              cp  ring  train
# seed
# 0          False  False  False            True  True   True
# 1          False  False  False            True  True   True
# 2           True  False  False           False  True  False
# 3           True  False  False           False  True  False
# 4          False  False   True           False  True  False
# 5          False  False   True           False  True  False
# 6           True  False   True           False  True  False
# 7           True  False   True           False  True  False
# 8           True   True   True           False  True  False
# 9           True   True   True           False  True  False
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_5_diabetes
# ================================================================================
# Directory: results_tf_5_diabetes
# Total expected files: 60
# Found files: 37
# Missing files: 23
#
# Missing files by type:
#
# CP - Missing 8 files:
#   - diabetes_cp_n_seed0_constrained.csv
#   - diabetes_cp_n_seed0.csv
#   - diabetes_cp_n_seed1_constrained.csv
#   - diabetes_cp_n_seed1.csv
#   - diabetes_cp_n_seed4.csv
#   - diabetes_cp_n_seed6_constrained.csv
#   - diabetes_cp_n_seed6.csv
#   - diabetes_cp_n_seed8.csv
#
# RING - Missing 11 files:
#   - diabetes_ring_n_seed0_constrained.csv
#   - diabetes_ring_n_seed1_constrained.csv
#   - diabetes_ring_n_seed2_constrained.csv
#   - diabetes_ring_n_seed2.csv
#   - diabetes_ring_n_seed3_constrained.csv
#   - diabetes_ring_n_seed4.csv
#   - diabetes_ring_n_seed5_constrained.csv
#   - diabetes_ring_n_seed6.csv
#   - diabetes_ring_n_seed7_constrained.csv
#   - diabetes_ring_n_seed8.csv
#   - diabetes_ring_n_seed9_constrained.csv
#
# TRAIN - Missing 4 files:
#   - diabetes_train_n_seed3.csv
#   - diabetes_train_n_seed5.csv
#   - diabetes_train_n_seed7.csv
#   - diabetes_train_n_seed9.csv
#
# Availability table (True = file exists, False = file missing):
#      constrained              non_constrained
# type          cp   ring train              cp   ring  train
# seed
# 0          False  False  True           False   True   True
# 1          False  False  True           False   True   True
# 2           True  False  True            True  False   True
# 3           True  False  True            True   True  False
# 4           True   True  True           False  False   True
# 5           True  False  True            True   True  False
# 6          False   True  True           False  False   True
# 7           True  False  True            True   True  False
# 8           True   True  True           False  False   True
# 9           True  False  True            True   True  False
#
#
# ================================================================================
# ANALYZING DIRECTORY: results_tf_6_diabetes
# ================================================================================
# Directory: results_tf_6_diabetes
# Total expected files: 60
# Found files: 33
# Missing files: 27
#
# Missing files by type:
#
# CP - Missing 8 files:
#   - diabetes_cp_n_seed0_constrained.csv
#   - diabetes_cp_n_seed2_constrained.csv
#   - diabetes_cp_n_seed2.csv
#   - diabetes_cp_n_seed4_constrained.csv
#   - diabetes_cp_n_seed4.csv
#   - diabetes_cp_n_seed6.csv
#   - diabetes_cp_n_seed8_constrained.csv
#   - diabetes_cp_n_seed8.csv
#
# RING - Missing 10 files:
#   - diabetes_ring_n_seed0_constrained.csv
#   - diabetes_ring_n_seed2_constrained.csv
#   - diabetes_ring_n_seed2.csv
#   - diabetes_ring_n_seed4_constrained.csv
#   - diabetes_ring_n_seed4.csv
#   - diabetes_ring_n_seed6_constrained.csv
#   - diabetes_ring_n_seed6.csv
#   - diabetes_ring_n_seed8_constrained.csv
#   - diabetes_ring_n_seed8.csv
#   - diabetes_ring_n_seed9_constrained.csv
#
# TRAIN - Missing 9 files:
#   - diabetes_train_n_seed1_constrained.csv
#   - diabetes_train_n_seed3_constrained.csv
#   - diabetes_train_n_seed3.csv
#   - diabetes_train_n_seed5_constrained.csv
#   - diabetes_train_n_seed5.csv
#   - diabetes_train_n_seed7_constrained.csv
#   - diabetes_train_n_seed7.csv
#   - diabetes_train_n_seed9_constrained.csv
#   - diabetes_train_n_seed9.csv
#
# Availability table (True = file exists, False = file missing):
#      constrained               non_constrained
# type          cp   ring  train              cp   ring  train
# seed
# 0          False  False   True            True   True   True
# 1           True   True  False            True   True   True
# 2          False  False   True           False  False   True
# 3           True   True  False            True   True  False
# 4          False  False   True           False  False   True
# 5           True   True  False            True   True  False
# 6           True  False   True           False  False   True
# 7           True   True  False            True   True  False
# 8          False  False   True           False  False   True
# 9           True  False  False            True   True  False

# %%
result_df_list[0].to_csv('diabetes_2.csv', index=False)
result_df_list[1].to_csv('diabetes_3.csv', index=False)
result_df_list[2].to_csv('diabetes_4.csv', index=False)
result_df_list[3].to_csv('diabetes_5.csv', index=False)
result_df_list[4].to_csv('diabetes_6.csv', index=False)

# %%
result_df_list[1]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0         True             True
# 1      cp     1         True             True
# 2      cp     2         True             True
# 3      cp     3         True             True
# 4      cp     4         True             True
# 5      cp     5         True             True
# 6      cp     6         True             True
# 7      cp     7         True             True
# 8      cp     8         True             True
# 9      cp     9         True             True
# 10   ring     0         True             True
# 11   ring     1         True             True
# 12   ring     2         True             True
# 13   ring     3         True             True
# 14   ring     4         True             True
# 15   ring     5         True             True
# 16   ring     6         True             True
# 17   ring     7         True             True
# 18   ring     8         True             True
# 19   ring     9         True             True
# 20  train     0         True             True
# 21  train     1         True             True
# 22  train     2         True             True
# 23  train     3         True             True
# 24  train     4         True             True
# 25  train     5         True             True
# 26  train     6         True             True
# 27  train     7         True             True
# 28  train     8         True             True
# 29  train     9         True             True

# %%
result_df_list[2]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0        False             True
# 1      cp     1        False             True
# 2      cp     2         True            False
# 3      cp     3         True            False
# 4      cp     4        False            False
# 5      cp     5        False            False
# 6      cp     6         True            False
# 7      cp     7         True            False
# 8      cp     8         True            False
# 9      cp     9         True            False
# 10   ring     0        False             True
# 11   ring     1        False             True
# 12   ring     2        False             True
# 13   ring     3        False             True
# 14   ring     4        False             True
# 15   ring     5        False             True
# 16   ring     6        False             True
# 17   ring     7        False             True
# 18   ring     8         True             True
# 19   ring     9         True             True
# 20  train     0        False             True
# 21  train     1        False             True
# 22  train     2        False            False
# 23  train     3        False            False
# 24  train     4         True            False
# 25  train     5         True            False
# 26  train     6         True            False
# 27  train     7         True            False
# 28  train     8         True            False
# 29  train     9         True            False

# %%
result_df_list[3]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0        False            False
# 1      cp     1        False            False
# 2      cp     2         True             True
# 3      cp     3         True             True
# 4      cp     4         True            False
# 5      cp     5         True             True
# 6      cp     6        False            False
# 7      cp     7         True             True
# 8      cp     8         True            False
# 9      cp     9         True             True
# 10   ring     0        False             True
# 11   ring     1        False             True
# 12   ring     2        False            False
# 13   ring     3        False             True
# 14   ring     4         True            False
# 15   ring     5        False             True
# 16   ring     6         True            False
# 17   ring     7        False             True
# 18   ring     8         True            False
# 19   ring     9        False             True
# 20  train     0         True             True
# 21  train     1         True             True
# 22  train     2         True             True
# 23  train     3         True            False
# 24  train     4         True             True
# 25  train     5         True            False
# 26  train     6         True             True
# 27  train     7         True            False
# 28  train     8         True             True
# 29  train     9         True            False

# %%
result_df_list[4]
# Out:
#      type  seed  constrained  non_constrained
# 0      cp     0        False             True
# 1      cp     1         True             True
# 2      cp     2        False            False
# 3      cp     3         True             True
# 4      cp     4        False            False
# 5      cp     5         True             True
# 6      cp     6         True            False
# 7      cp     7         True             True
# 8      cp     8        False            False
# 9      cp     9         True             True
# 10   ring     0        False             True
# 11   ring     1         True             True
# 12   ring     2        False            False
# 13   ring     3         True             True
# 14   ring     4        False            False
# 15   ring     5         True             True
# 16   ring     6        False            False
# 17   ring     7         True             True
# 18   ring     8        False            False
# 19   ring     9        False             True
# 20  train     0         True             True
# 21  train     1        False             True
# 22  train     2         True             True
# 23  train     3        False            False
# 24  train     4         True             True
# 25  train     5        False            False
# 26  train     6         True             True
# 27  train     7        False            False
# 28  train     8         True             True
# 29  train     9        False            False
